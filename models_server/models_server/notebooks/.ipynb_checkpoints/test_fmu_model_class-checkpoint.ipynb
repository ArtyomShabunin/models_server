# %% [markdown]
# ## Тестирование класса FMU_model

# %%
import time

# %%
import sys
sys.path.append('../')

# %%
from models_server import db
from models_server.models import Model, Variable, Measurement, Achive, Task

# %%
from models_server.fmu_model import *

# %%
import pandas as pd
import numpy as np

# %%
def write_to_db(df, db, diff, time):
    df['to_db'] = True
    df.loc[abs((df.sol - df.prev_sol) / df.sol) > diff, 'to_db'] = False
    df.loc[(df.sol - df.prev_sol) == 0, 'to_db'] = False
    flag = 0
    for index, row in df.loc[df.to_db, ('id', 'sol')].iterrows():
        db.session.add(Measurement(achive_id=achive.id, variable_id=row['id'], value=row['sol'], time=time))
        flag += 1
    db.session.commit()
    print('На шаге {} записано {} переменных'.format(time, flag))

# %%
user_id = 3
model_id = 1

# %%
# Создаем задачу в базе данных
task = Task(model_id=model_id, user_id=user_id)
db.session.add(task)
db.session.commit()

# %%
# Инстанс классса
new_model = fmu_model('../fmu/TPPSim02.Pipes.Tests.PipeChannelFMU_Test.fmu')

# %%
# Инициализация модели
# Здесь должно быть задание входных параметров
new_model.initialize()
# Out:
# Инициализация модели выполнена

# %%
# Создание архива в базе данных
achive = Achive(user_id=user_id, task_id=task.id, model_id=model_id)
db.session.add(achive)
db.session.commit()

# %%
# Получаем значения переменных
db_model = Model.query.get(1)
var = db_model.variables.all()

# %%
df = pd.DataFrame({
    'id':[i.id for i in var],
    'name':[i.name for i in var],
    'vref':[new_model.model.get_variable_valueref(i.name) for i in var],
    'sol':np.nan,
    'prev_sol':np.nan
})

# %%
df['sol'] = new_model.model.get_real(df.vref)

# %%
#     time.sleep(1)
while True
    # Запись переменных в БД
    write_to_db(df, db, 1e-4, new_model.model.time)
    # Итегрирование
    new_model.integrate()
    # Сохранение предыдущего и текущего решений
    df['prev_sol'] = df.sol
    df.sol = new_model.model.get_real(df.vref)
# Out:
# На шаге 0.07 записано 74 переменных

# %%
new_model.model.get_log()
# Out:
# ['FMIL: module = FMI2XML, log level = 4: Found model identifiers for ModelExchange and CoSimulation',
#  "FMIL: module = FMILIB, log level = 4: Loading 'linux64' binary with 'default' platform types",
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2Instantiate: GUID={06d03f16-06e5-4f0c-bddf-fdbfbf942c5b}',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2SetupExperiment: toleranceDefined=1 tolerance=0.001 startTime=0 stopTimeDefined=0 stopTime=700',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2EnterInitializationMode...',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2ExitInitializationMode...',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2EnterInitializationMode: succeed',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2ExitInitializationMode: succeed',
#  'FMIL: module = Model, log level = 4: [logEvents][FMU status:OK] fmi2EnterEventMode',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2NewDiscreteStates',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2EventUpdate: Start Event Update! Next Sample Event 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2EventUpdate: newDiscreteStatesNeeded false',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2EventUpdate: Checked for Sample Events! Next Sample Event 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2EnterContinuousTimeMode',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_1.Channel[1,1].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_1.Channel[1,2].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_1.Channel[1,3].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_1.Channel[1,4].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_1.Channel[1,5].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,1].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,2].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,3].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,4].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,5].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,1].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,2].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,3].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,4].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,5].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,1].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,2].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,3].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,4].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_2.Channel[1,5].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,1].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,2].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,3].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,4].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,5].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,1].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,2].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,3].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,4].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,5].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,1].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,2].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,3].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,4].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: channel_3.Channel[1,5].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: valve_1.filter.x[1] = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: valve_1.filter.x[2] = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: valve_2.filter.x[1] = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetContinuousStates: valve_2.filter.x[2] = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetNominalsOfContinuousStates: x_nominal[0..38] = 1.0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z0 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z1 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z2 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z3 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z4 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z5 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z6 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z7 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z8 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z9 = -1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z10 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z11 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z12 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z13 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetEventIndicators: z14 = 1',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].D_flow_v = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].pv = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_1.Channel[1,1].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_1.Channel[1,2].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_1.Channel[1,3].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_1.Channel[1,4].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_1.Channel[1,5].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,1].D_flow_v) = 0.2106086641300618',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,2].D_flow_v) = 0.2106086641300618',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,3].D_flow_v) = 0.2106086641300618',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,4].D_flow_v) = 0.2106086641300618',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,5].D_flow_v) = 0.1836627191549294',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,1].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,2].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,3].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,4].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,5].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,1].pv) = 38880.25726353972',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,2].pv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,3].pv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,4].pv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_2.Channel[1,5].pv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,1].D_flow_v) = 0.2106086641300618',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,2].D_flow_v) = 0.2106086641300618',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,3].D_flow_v) = 0.2106086641300618',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,4].D_flow_v) = 0.2106086641300618',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,5].D_flow_v) = 0.2106086641300618',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,1].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,2].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,3].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,4].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,5].hv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,1].pv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,2].pv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,3].pv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,4].pv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: der(channel_3.Channel[1,5].pv) = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = -0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].Dv = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].Dv = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].Dv = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].Dv = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].Dv = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].H[1] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].H[2] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].H[1] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].H[2] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].H[1] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].H[2] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].H[1] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].H[2] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].H[1] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].H[2] = 191171.8950403322',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].dp_fric = 0.1396552256365658',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].dp_fric = 0.139644913136706',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].dp_fric = 0.1396346013831143',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].dp_fric = 0.1396242903757402',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].dp_fric = 0.1396139801145328',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].dp_piez = -14.90222236514701',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].dp_piez = -14.90332286633708',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].dp_piez = -14.90442345042284',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].dp_piez = -14.90552411741045',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].drdh = -6.669273177136709e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].drdh = -6.669766092508635e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].drdh = -6.67025904506524e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].drdh = -6.67075203480929e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].drdp = 3.800826005852165e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].drdp = 3.80082631060005e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].drdp = 3.800826615369908e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].drdp = 3.800826920161745e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].heatTransfer.Ts = 573.1496416224134',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].heatTransfer.Ts = 573.1498214372771',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].heatTransfer.Ts = 573.1500012655308',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].heatTransfer.Ts = 573.1501811071752',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].p[2] = 200073.8184417355',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].pv = 200014.7614667212',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].pv = 200029.5240441732',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].pv = 200044.2877324382',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].pv = 200059.0525315982',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].stateFlow.d = 0.7598018877571345',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].stateFlow.d = 0.7598579977024306',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].stateFlow.d = 0.7599141118742303',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].stateFlow.d = 0.7599702302728478',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].w_flow_v = 1.158751370139723',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].w_flow_v = 1.158665804968154',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].w_flow_v = 1.158580245988542',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].w_flow_v = 1.158494693200468',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].w_flow_v = 1.15840914660351',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].p[2] = 200001.9060357063',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].Dv = 0.01',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].H[1] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].H[2] = 30720.84068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].Xi_flow = 0.2738031041553197',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].dp_fric = 0.003606411610901493',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].dp_piez = -14.9011219468465',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].drdh = -6.668780298946711e-07',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].w_flow_v = 0.1862084184878668',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].D[1] = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = -0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].D[1] = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = -0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].D[1] = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = -0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].D[1] = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = -0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[1] = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].D_flow_v = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].D_flow_v = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].D_flow_v = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].D_flow_v = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D_flow_v = 0.06222873163037074',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].heatTransfer.Ts = 573.1496416224134',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].heatTransfer.Ts = 573.1498214372771',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].heatTransfer.Ts = 573.1500012655308',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].heatTransfer.Ts = 573.1501811071752',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].stateFlow.d = 0.7598018877571345',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].stateFlow.d = 0.7598579977024306',
# ...
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].drdp = 3.800825701126262e-06',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].lambda_tr = 0.01642818624931918',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,1].w_flow_v = 0.225425524755368',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,2].w_flow_v = 0.225425524755368',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,3].w_flow_v = 0.225425524755368',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,4].w_flow_v = 0.225425524755368',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_3.Channel[1,5].w_flow_v = 0.225425524755368',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].D[1] = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = 0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].D[1] = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = 0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].D[1] = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = 0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].D[1] = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = 0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[1] = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].D_flow_v = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].D_flow_v = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].D_flow_v = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].D_flow_v = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D_flow_v = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].heatTransfer.Ts = 573.1496504979344',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].heatTransfer.Ts = 573.1498391882851',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].heatTransfer.Ts = 573.1500278919917',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].heatTransfer.Ts = 573.1502166090551',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].stateFlow.d = 0.7597457820380302',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].stateFlow.d = 0.7598046572990188',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].stateFlow.d = 0.7598635367804447',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].stateFlow.d = 0.7599224204826368',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].stateFlow.d = 0.7599813084059263',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: Source_2.p_in = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].pv = 200015.4901357284',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].pv = 200030.9813805539',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].pv = 200046.4737345629',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].pv = 200061.9671978421',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: Source_2.p_in = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].pv = 200015.4901357284',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].pv = 200015.4901357284',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].pv = 200030.9813805539',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].pv = 200030.9813805539',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].pv = 200046.4737345629',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].pv = 200046.4737345629',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].pv = 200061.9671978421',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].pv = 200061.9671978421',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: Source_2.p_in = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].heatTransfer.Ts = 573.1496504979344',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].heatTransfer.Ts = 573.1498391882851',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].heatTransfer.Ts = 573.1500278919917',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].heatTransfer.Ts = 573.1502166090551',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: Source_2.p_in = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,2].pv = 200015.4901357284',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,3].pv = 200030.9813805539',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,4].pv = 200046.4737345629',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].pv = 200061.9671978421',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,1].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.waterIn.m_flow = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: Source_2.p_in = 200000',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].hv = 3072084.068431032',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].D[2] = 0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_1.Channel[1,5].p[2] = 200077.4617704782',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].D[1] = -0.1277983015062696',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].D[2] = -0.01210608664130062',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].D_flow_v = 0.01210608664130062',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].D[2] = -0.01210608664130062',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].D_flow_v = 0.01210608664130062',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].D[2] = -0.01210608664130062',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].D_flow_v = 0.01210608664130062',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].D[2] = -0.01210608664130062',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].D_flow_v = 0.01210608664130062',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].D[2] = -0.01183662719154929',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].heatTransfer.Q_flow = 0',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].heatTransfer.Ts = 573.1541975688069',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,2].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,3].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,4].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,5].heatTransfer.Ts = 573.1494618209383',
#  'FMIL: module = Model, log level = 4: [logFmi2Call][FMU status:OK] fmi2GetReal: channel_2.Channel[1,1].stateFlow.d = 0.7612235532178271',
#  ...]

# %%
# for m in Measurement.query.all():
#     db.session.delete(m)
# db.session.commit()
